# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />

# %% [markdown]
# <img src="data:image/png;base64,..." style="width:100%; max-width:1280px;" />
